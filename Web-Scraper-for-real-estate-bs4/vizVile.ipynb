# %%
from re import A
import altair as alt
import pandas as pd
from vega_datasets import data

alt.renderers.enable("mimetype")    

source = pd.read_csv(r"C:\Users\Acrylic\Desktop\Chatbot\Web scraper\Master File Vile.CSV")
chartMax = alt.data_transformers.disable_max_rows()

# %%
print(source)
source.dtypes
# Out:
#       price  priceRounded priceRange  eur/mp  areaRaw  areaRounded totalArea  \
# 0    149.90           150   140-155k     961   156.00          156       105
# 1    147.00           147   140-155k    1235   119.00          119       200
# 2    135.00           135   128-139k    1089   124.00          124       150
# 3    135.00           135   128-139k    1378    98.00           98       171
# 4     76.18            76     69-95k     762   100.00          100       200
# ..      ...           ...        ...     ...      ...          ...       ...
# 291  145.00           145   140-155k    1051   138.00          138       188
# 292   79.99            80     69-95k    1333    60.00           60       170
# 293  750.00           750   Over 300     490  1531.00         1531      2852
# 294  144.99           145   140-155k    1054   137.58          138       196
# 295  750.00           750   Over 300     490  1531.00         1531      2852
#
#       areaRange  rooms no_of_levels location
# ...

# %%
from matplotlib.pyplot import title

alt.Chart(source).mark_point().encode(
    y=alt.Y('areaRaw:Q' ,axis=alt.Axis(title='Suprafta')),
    x=alt.X('price:Q', axis=alt.Axis( title='Pret')),
    color= 'rooms:N',
    tooltip= [alt.Tooltip(field ='price', title = 'Pret', type ='quantitative'),
              alt.Tooltip(field ='eur/mp', title = 'Eur/mp', type = 'quantitative'),
              alt.Tooltip(field ='rooms', title = 'Nr_camere', type = 'quantitative'),
              alt.Tooltip(field ='areaRaw', title = 'Suprafata', type = 'quantitative'),
              alt.Tooltip(field = 'location', title = 'Locatie', type = 'nominal')
             ] 
).interactive()
# Out:
# c:\Users\Acrylic\AppData\Local\Programs\Python\Python310\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(source).mark_circle().encode(
    alt.X(alt.repeat("column") , type = 'quantitative'),
    alt.Y(alt.repeat("row"), type= 'quantitative'),
    alt.Color('location', type = 'nominal',
             scale = alt.Scale(range = ['#3F51B5','#9C27B0','#70235B','#1f9fb4','#FF5733'])),
  
    tooltip= [alt.Tooltip(field ='price', title = 'Pret', type ='quantitative'),
              alt.Tooltip(field ='eur/mp', title = 'Eur/mp', type = 'quantitative'),
              alt.Tooltip(field ='rooms', title = 'Nr_camere', type = 'quantitative'),
              alt.Tooltip(field ='areaRaw', title = 'Suprafata', type = 'quantitative'),
              alt.Tooltip(field = 'location', title = 'Locatie', type = 'nominal')
             ]
).properties(
   
    width  = 500,
    height = 250
).repeat(
        row = ['price','areaRaw','rooms'],
        column = ['rooms', 'areaRaw' , 'price']
).interactive()
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
from pandas import interval_range


histArea = alt.Chart(source).mark_bar(clip=True).encode(
    y=alt.Y('count(areaRounded):Q' ,axis=alt.Axis(title='Nr de apartamente cu suprafata de ')),
    x=alt.X('areaRounded:Q', axis=alt.Axis( title='Suprafata'),scale=alt.Scale(domain=(0, 170))),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu suprafata de'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('areaRounded', title = 'Suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim')]
)

histPrice = alt.Chart(source).mark_bar(clip=True).encode(
    y=alt.Y('count(priceRounded):Q' ,axis=alt.Axis(title='Nr de apartamente cu pretul de ')),
    x=alt.X('priceRounded:Q', axis=alt.Axis( title='Pret'), scale=alt.Scale(domain=(95, 200))),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu pretul de'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima'),
            
                 ]
)

histPriceRange = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(priceRange):Q' ,axis=alt.Axis(title='Nr de apartamente cu intervalul de pret de ')),
    x=alt.X('priceRange:N', axis=alt.Axis( title='Pret')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu intervalul de pret de'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima'),]
)

histAreaRange = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(areaRange):Q' ,axis=alt.Axis(title='Nr de apartamente cu suprafta de ')),
    x=alt.X('areaRange:N', axis=alt.Axis( title='Suprafta interval')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu suprafta de'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim')]
)

chart3 = histArea & histPrice | histPriceRange & histAreaRange
chart3
# Out:
# c:\Users\Acrylic\AppData\Local\Programs\Python\Python310\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
histLoc = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(location):Q' ,axis=alt.Axis(title='Nr de apartamente in locatia de ')),
    x=alt.X('location:N', axis=alt.Axis( title='Locatie')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente in locatia de'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima')]
)

histRooms = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(rooms):Q' ,axis=alt.Axis(title='Nr de apartamente pt fiecare tip ')),
    x=alt.X('rooms:O', axis=alt.Axis( title='Camere')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente pt fiecare tip'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima')]
)

histFloor = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(no_of_levels):Q' ,axis=alt.Axis(title='Nr de apartamente la etajul')),
    x=alt.X('no_of_levels:N', axis=alt.Axis( title='Etaj')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente la etajul'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima')]
)
chart4 = histLoc | histRooms | histFloor
chart4
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart5 = alt.Chart(source).mark_point().encode(
    x='eur/mp:Q',
    y='areaRaw:Q',
    color='rooms:N',
    tooltip = [ alt.Tooltip(field = 'price', title = 'Pret', type = 'quantitative'),
                alt.Tooltip(field ='eur/mp', title = 'Eur/mp', type = 'quantitative'),
                alt.Tooltip(field ='rooms', title = 'Nr_camere', type = 'quantitative'),
                alt.Tooltip(field ='areaRaw', title = 'Suprafata', type = 'quantitative'),
                alt.Tooltip(field = 'location', title = 'Locatie', type = 'nominal')]
).properties(
    width  = 300,
    height = 500
).interactive()


chart5
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
histEurPerMP = alt.Chart(source).mark_bar(clip=True).encode(
    y=alt.Y('count(eur/mp):Q' ,axis=alt.Axis(title='Nr de apartamente cu pretul de eur/mp ')),
    x=alt.X('eur/mp:O', axis=alt.Axis( title='Eur/mp')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente pt fiecare tip'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafata')]
)
histEurPerMP
# Out:
# <VegaLite 4 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart1 = alt.Chart(source).mark_point().encode(
    y=alt.Y('areaRaw:Q' ,axis=alt.Axis(title='Suprafta')),
    x=alt.X('price:Q', axis=alt.Axis( title='Pret')),
    color= 'rooms:N',
    tooltip= [alt.Tooltip(field ='price', title = 'Pret', type ='quantitative'),
              alt.Tooltip(field ='eur/mp', title = 'Eur/mp', type = 'quantitative'),
              alt.Tooltip(field ='rooms', title = 'Nr_camere', type = 'quantitative'),
              alt.Tooltip(field ='areaRaw', title = 'Suprafata', type = 'quantitative'),
              alt.Tooltip(field = 'location', title = 'Locatie', type = 'nominal')
             ] 
).interactive() 

chart2 = alt.Chart(source).mark_circle().encode(
    alt.X(alt.repeat("column") , type = 'quantitative'),
    alt.Y(alt.repeat("row"), type= 'quantitative'),
    alt.Color('location', type = 'nominal',
             scale = alt.Scale(range = ['#3F51B5','#9C27B0','#70235B','#1f9fb4','#FF5733'])),
  
    tooltip= [alt.Tooltip(field ='price', title = 'Pret', type ='quantitative'),
              alt.Tooltip(field ='eur/mp', title = 'Eur/mp', type = 'quantitative'),
              alt.Tooltip(field ='rooms', title = 'Nr_camere', type = 'quantitative'),
              alt.Tooltip(field ='areaRaw', title = 'Suprafata', type = 'quantitative'),
              alt.Tooltip(field = 'location', title = 'Locatie', type = 'nominal')
             ]
).properties(
   
    width  = 500,
    height = 250
).repeat(
        row = ['price','areaRaw','rooms'],
        column = ['rooms', 'areaRaw' , 'price']
).interactive()     

histArea = alt.Chart(source).mark_bar(clip=True).encode(
    y=alt.Y('count(areaRounded):Q' ,axis=alt.Axis(title='Nr de apartamente cu suprafata de ')),
    x=alt.X('areaRounded:Q', axis=alt.Axis( title='Suprafata'),scale=alt.Scale(domain=(0, 170))),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu suprafata de'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('areaRounded', title = 'Suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim')]
)

histPrice = alt.Chart(source).mark_bar(clip=True).encode(
    y=alt.Y('count(priceRounded):Q' ,axis=alt.Axis(title='Nr de apartamente cu pretul de ')),
    x=alt.X('priceRounded:Q', axis=alt.Axis( title='Pret'), scale=alt.Scale(domain=(95, 200))),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu pretul de'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima'),
            
                 ]
)

histPriceRange = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(priceRange):Q' ,axis=alt.Axis(title='Nr de apartamente cu intervalul de pret de ')),
    x=alt.X('priceRange:N', axis=alt.Axis( title='Pret')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu intervalul de pret de'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima'),]
)

histAreaRange = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(areaRange):Q' ,axis=alt.Axis(title='Nr de apartamente cu suprafta de ')),
    x=alt.X('areaRange:N', axis=alt.Axis( title='Suprafta interval')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente cu suprafta de'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim')]
)

chart3 = histArea & histPrice | histPriceRange & histAreaRange

histLoc = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(location):Q' ,axis=alt.Axis(title='Nr de apartamente in locatia de ')),
    x=alt.X('location:N', axis=alt.Axis( title='Locatie')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente in locatia de'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima')]
)

histRooms = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(rooms):Q' ,axis=alt.Axis(title='Nr de apartamente pt fiecare tip ')),
    x=alt.X('rooms:O', axis=alt.Axis( title='Camere')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente pt fiecare tip'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima')]
)

histFloor = alt.Chart(source).mark_bar().encode(
    y=alt.Y('count(no_of_levels):Q' ,axis=alt.Axis(title='Nr de apartamente la etajul')),
    x=alt.X('no_of_levels:N', axis=alt.Axis( title='Etaj')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente la etajul'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafta'),
               alt.Tooltip ('min(priceRounded)', title = 'Pret minim'),
               alt.Tooltip ('max(priceRounded)', title = 'Pret maxim'),
               alt.Tooltip ('min(areaRounded)', title = 'Suprafta minima'),
               alt.Tooltip ('max(areaRounded)', title = 'Suprafta maxima')]
)
chart4 = histLoc | histRooms | histFloor

chart5 = alt.Chart(source).mark_point().encode(
    x='eur/mp:Q',
    y='areaRaw:Q',
    color='rooms:N',
    tooltip = [ alt.Tooltip(field = 'price', title = 'Pret', type = 'quantitative'),
                alt.Tooltip(field ='eur/mp', title = 'Eur/mp', type = 'quantitative'),
                alt.Tooltip(field ='rooms', title = 'Nr_camere', type = 'quantitative'),
                alt.Tooltip(field ='areaRaw', title = 'Suprafata', type = 'quantitative'),
                alt.Tooltip(field = 'location', title = 'Locatie', type = 'nominal')]
).properties(
    width  = 700,
    height = 500
).interactive()

histEurPerMP = alt.Chart(source).mark_bar(clip=True).encode(
    y=alt.Y('count(eur/mp):Q' ,axis=alt.Axis(title='Nr de apartamente cu pretul de eur/mp ')),
    x=alt.X('eur/mp:O', axis=alt.Axis( title='Eur/mp')),
    tooltip = [alt.Tooltip ('count()', title = 'Nr de apartamente pt fiecare tip'),
               alt.Tooltip('mean(price)', title = 'Medie pret'),
               alt.Tooltip('mean(areaRaw)', title = 'Medie suprafata')]
)

( chart1 & chart2 & chart3 & chart4 & chart5 & histEurPerMP).save('chartVile.html')
